# %% [markdown]
# # Proyek Analisis Data: Submission Proyek
# - **Nama:** Muhammad Wildan
# - **Email:** wildanmuhammad748@gmail.com
# - **ID Dicoding:** 53XE12880ZRN

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Kategori produk apakah yang menghasilkan total revenue (pendapatan) tertinggi dan terendah sepanjang tahun 2023?
#
# - **Pertanyaan 2:** Bagaimana demografi pelanggan (berdasarkan jenis kelamin dan rentang usia) yang paling aktif melakukan transaksi pembelian?
# - ...

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
# Memuat data customers
customers_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/customers.csv")
print("Customers DataFrame:", customers_df.shape)

# Memuat data orders
orders_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/orders.csv")
print("Orders DataFrame:", orders_df.shape)

# Memuat data products
product_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/products.csv")
print("Products DataFrame:", product_df.shape)

# Memuat data sales
sales_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/sales.csv")
print("Sales DataFrame:", sales_df.shape)
# Out:
# Customers DataFrame: (1007, 9)
# Orders DataFrame: (1000, 5)
# Products DataFrame: (1266, 8)
# Sales DataFrame: (5000, 6)

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying ... problem

# %%
print("--- INFO CUSTOMERS ---")
print(customers_df.info())
print("\nJumlah duplikasi:", customers_df.duplicated().sum())
print("Missing values:\n", customers_df.isnull().sum())

print("\n--- INFO ORDERS ---")
print(orders_df.info())
print("\nJumlah duplikasi:", orders_df.duplicated().sum())
print("Missing values:\n", orders_df.isnull().sum())

print("\n--- INFO PRODUCTS ---")
print(product_df.info())
print("\nJumlah duplikasi:", product_df.duplicated().sum())
print("Missing values:\n", product_df.isnull().sum())

print("\n--- INFO SALES ---")
print(sales_df.info())
print("\nJumlah duplikasi:", sales_df.duplicated().sum())
print("Missing values:\n", sales_df.isnull().sum())
# Out:
# --- INFO CUSTOMERS ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB
# None
#
# Jumlah duplikasi: 6
# Missing values:
#  customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64
#
# --- INFO ORDERS ---
# ...

# %% [markdown]
# **Steps to Take:**
# - xxx
# - xxx

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
# Membersihkan missing values pada order_date dan delivery_date di orders_df jika ada
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])
orders_df['delivery_date'] = pd.to_datetime(orders_df['delivery_date'])

# Memeriksa kembali informasi setelah dibersihkan
print("Tipe data orders_df:")
print(orders_df.dtypes)
print("\nSisa missing values orders_df:", orders_df.isna().sum().sum())
# Out:
# Tipe data orders_df:
# order_id                  int64
# customer_id               int64
# payment                   int64
# order_date       datetime64[ns]
# delivery_date    datetime64[ns]
# dtype: object
#
# Sisa missing values orders_df: 0

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Menggabungkan data sales dan product untuk melihat penjualan berdasarkan produk/kategori
product_sales_df = pd.merge(
    sales_df,
    product_df,
    on='product_id',
    how='inner'
)

print("Contoh data hasil gabungan sales dan product:")
print(product_sales_df.head())

# Eksplorasi total penjualan per kategori produk
print("\nTotal harga/pendapatan berdasarkan kategori produk:")
print(product_sales_df.groupby('product_type').agg({
    'price': 'sum',
    'quantity_x': 'sum'
}))
# Out:
# Contoh data hasil gabungan sales dan product:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2        212.0
# 1         1         1         481             118           1        118.0
# 2         2         1           2              96           3        288.0
# 3         3         1        1002             106           2        212.0
# 4         4         1         691             113           3        339.0
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Menyiapkan data untuk pertanyaan 1 (Total penjualan berdasarkan kategori produk)
sum_order_items_df = product_sales_df.groupby("product_type").quantity_x.sum().sort_values(ascending=False).reset_index()

# Membuat visualisasi barplot
plt.figure(figsize=(10, 5))
sns.barplot(
    x="quantity_x",
    y="product_type",
    data=sum_order_items_df,
    palette="viridis"
)
plt.title("Performa Penjualan Berdasarkan Kategori Produk", fontsize=15)
plt.xlabel("Total Quantity Terjual", fontsize=12)
plt.ylabel("Kategori Produk", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_3268/2566642784.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Menyiapkan data untuk pertanyaan 2 (Demografi berdasarkan gender)
gender_customer_df = customers_df.groupby(by="gender").customer_id.nunique().reset_index()
gender_customer_df.rename(columns={"customer_id": "customer_count"}, inplace=True)

# Membuat visualisasi barplot demografi
plt.figure(figsize=(8, 5))
sns.barplot(
    x="gender",
    y="customer_count",
    data=gender_customer_df,
    palette="muted"
)
plt.title("Jumlah Pelanggan Berdasarkan Jenis Kelamin", fontsize=15)
plt.xlabel("Jenis Kelamin", fontsize=12)
plt.ylabel("Jumlah Pelanggan", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_3268/1866278829.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# - **Conclusion pertanyaan 1:** Kategori produk tertentu mendominasi total penjualan secara signifikan, sementara kategori lainnya memiliki kontribusi paling rendah sepanjang periode analisis.
#
# - **Conclusion pertanyaan 2:** Mayoritas pelanggan yang aktif melakukan transaksi didominasi oleh kelompok demografi tertentu berdasarkan data jenis kelamin dan rentang usia.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Rekomendasi Action Item:**
# - Memperbanyak alokasi stok dan memberikan penawaran khusus untuk kategori produk yang memiliki performa penjualan tertinggi.
# - Menargetkan strategi pemasaran dan promosi yang lebih personal kepada kelompok demografi pelanggan yang paling aktif melakukan transaksi.
